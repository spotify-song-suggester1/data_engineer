# %%
import pandas as pd
import seaborn as sns
import numpy as numpy
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %%
songs=pd.read_csv('my_all_tracks.csv')

# %%
songs.head()
# Out:
#    duration_ms_x  explicit                      id  is_local  \
# 0         181929      True  6gxKUmycQX7uyMwJcweFjp     False
# 1         209848      True  4GurWpxvH3NoWz9f9wirPq     False
# 2         239320      True  6Ius4TC0L3cN74HT7ENE6e     False
# 3         250626     False  7a86XRg84qjasly9f6bPSD     False
# 4         184153     False  1BYZxKSf0aTxp8ZFoeyM3d     False
#
#                                  name  popularity  \
# 0             We Paid (feat. 42 Dugg)          87
# 1                 Wet (She Got That…)          77
# 2                          Wet Dreamz          78
# 3  We Are Young (feat. Janelle Monáe)          74
# 4          we fell in love in october          79
#
#                                 album.name album.release_date  danceability  \
# 0                         My Turn (Deluxe)         2020-05-01         0.926
# 1                      Wet (She Got That…)         2020-02-14         0.695
# ...

# %%
list(songs.columns)
# Out:
# ['duration_ms_x',
#  'explicit',
#  'id',
#  'is_local',
#  'name',
#  'popularity',
#  'album.name',
#  'album.release_date',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms_y',
#  'time_signature']

# %%
songs.dtypes
# Out:
# duration_ms_x           int64
# explicit                 bool
# id                     object
# is_local                 bool
# name                   object
# popularity              int64
# album.name             object
# album.release_date     object
# danceability          float64
# energy                float64
# key                     int64
# loudness              float64
# mode                    int64
# speechiness           float64
# acousticness          float64
# instrumentalness      float64
# liveness              float64
# valence               float64
# tempo                 float64
# duration_ms_y           int64
# time_signature          int64
# dtype: object

# %%
songs['album.release_date'] = pd.to_datetime(songs['album.release_date'])

# %%
songs = songs.sort_values(by=['album.release_date'], ascending=False)

# %%
# sns.set(rc={'figure.figsize':(5,20)})
# sns.set_style('ticks')
# fig, ax = plt.subplots()
# fig.set_size_inches(18.5, 10.5)

sns.relplot(x="album.release_date", y="popularity", data=songs, height=5, aspect=16/9);

# %%
sns.relplot(x="danceability", y="popularity", data=songs, height=5, aspect=16/9);

# %%
sns.relplot(x="tempo", y="popularity", data=songs, height=5, aspect=16/9);

# %%
songs.describe()
# Out:
#        duration_ms_x  popularity  danceability      energy         key  \
# count     800.000000  800.000000    800.000000  800.000000  800.000000
# mean   212878.223750   68.076250      0.643530    0.641847    5.188750
# std     55875.185278   10.913034      0.156012    0.196534    3.593642
# min     49213.000000    0.000000      0.120000    0.077400    0.000000
# 25%    181048.250000   63.000000      0.538000    0.505000    2.000000
# 50%    207712.500000   69.000000      0.641000    0.659000    5.000000
# 75%    246735.000000   75.000000      0.758250    0.801250    8.000000
# max    547733.000000  100.000000      0.974000    0.998000   11.000000
#
#          loudness       mode  speechiness  acousticness  instrumentalness  \
# count  800.000000  800.00000   800.000000    800.000000        800.000000
# mean    -7.115434    0.64875     0.106910      0.230189          0.032010
# std      3.432374    0.47766     0.111355      0.255531          0.136898
# ...

# %%
songs.sort_values(by=['popularity'], ascending=False)
# Out:
#      duration_ms_x  explicit                      id  is_local  \
# 460         181733      True  7ytR5pFWmSjzHJIeQkgog4     False
# 600         181733      True  7ytR5pFWmSjzHJIeQkgog4     False
# 440         181733      True  7ytR5pFWmSjzHJIeQkgog4     False
# 602         176546     False  62aP9fBQKYKxi7PDXwcUAS     False
# 780         223480      True  4nK5YrxbMGZstTLbvj6Gxw     False
# ..             ...       ...                     ...       ...
# 317         251493     False  23dTjffjaS8rMaMXjiSe45     False
# 539         466786     False  5lJDzCCuXJk45xfGGDA3hE     False
# 519         466786     False  5lJDzCCuXJk45xfGGDA3hE     False
# 364         162440     False  2FwHIq7hVfR3np5uOpHVQZ     False
# 365         163626      True  69CQe4ekUZ7txcSfEXYFW9     False
#
#                                                name  popularity  \
# 460                    ROCKSTAR (feat. Roddy Ricch)         100
# 600                    ROCKSTAR (feat. Roddy Ricch)         100
# ...

# %%
songs['id'].value_counts()
# Out:
# 01JPQ87UHeGysPVwTqMJHK    3
# 72ahyckBJfTigJCFCviVN7    3
# 61Ivix5DTnDPVjp1dgLyov    3
# 7ytR5pFWmSjzHJIeQkgog4    3
# 6gxKUmycQX7uyMwJcweFjp    3
#                          ..
# 0Vb2xjYal6mITwIfblUX3a    1
# 6WCeFNVAXUtNczb7lqLiZU    1
# 69ghzc538EQSVon2Gm3wrr    1
# 1rqqCSm0Qe4I9rUvWncaom    1
# 1fLibtVj3MrNTwRZq5yUOs    1
# Name: id, Length: 525, dtype: int64

# %%
songs2=pd.read_csv('prev_all_tracks.csv')

# %%
songs2['id'].value_counts()
# Out:
# 3fKeB6lVdwe6rUT2mnLo08    200
# 1chmZUBdfxoLWN1LCZ6HLO    200
# 6r7bDk4J0Okw4ezTBUQXo3    200
# 30o8E8pmxyWDVvjud2WE5i    200
# 3yUcGn9extbg41SdEXF5Rx    200
#                          ...
# 0an62enauxbEFNi2d7KeKp      1
# 474G1Na0BXI85MCAplG7Py      1
# 7efFijVJQa7ehm2uXBm4Fl      1
# 7ALEnl4jSyJmg956AbTNoY      1
# 45o59c40yEiGroGHtcDtyy      1
# Name: id, Length: 1640, dtype: int64
